# %%
import random
import matplotlib.pyplot as plt
import numpy as np
from treasure_env import MultiTreasureHunterMDP,  LEFT, RIGHT, UP, DOWN, ACTIONS

# %% [markdown]
# TODO:
# - [ ] porównanie agentów pasywnego
# - [X] porównanie agentów aktywnego
# - [ ] porównanie monte carlo (napisać własny)
# - [ ] aproksymacja funkcji wartości (napisać własny)

# %% [markdown]
# # Transformacja stanu dla multi-agent learning
#
# Funkcja `get_agent_state` przekształca globalny stan środowiska na stan z perspektywy konkretnego agenta:
# - Agent zawsze widzi siebie jako "pierwszy" w tupli
# - Pozwala uczyć się polityki niezależnej od ID agenta
# - Umożliwia współdzielenie wiedzy między agentami
#
# ## Integracja z zewnętrznymi plikami
#
# **✅ Metoda dostępna w klasie środowiska:** `env.get_agent_state(state, agent_id)`
#
# Ta metoda jest zaimplementowana w:
# - `treasure_env.py` - klasa `MultiTreasureHunterMDP`
# - `game_active.py` - używa metody z klasy środowiska
# - Ten notebook - zawiera funkcję pomocniczą (wrapper) dla wygody

# %%
def get_agent_state(state, agent_id):
    pos1, pos2, treasures, hold1, hold2 = state
    
    if agent_id == '1':
        return (pos1, pos2, treasures, hold1, hold2)
    else:
        return (pos2, pos1, treasures, hold2, hold1)

# %% [markdown]
# ## Przykład użycia metody z klasy środowiska
#
# ```python
# # Sposób 1: Używając metody z klasy środowiska (ZALECANE)
# env = MultiTreasureHunterMDP(MAP1)
# state = env.reset()
#
# state1 = env.get_agent_state(state, '1')  # Stan z perspektywy Agent 1
# state2 = env.get_agent_state(state, '2')  # Stan z perspektywy Agent 2
#
# # Sposób 2: Używając funkcji pomocniczej (dla kompatybilności z notebookiem)
# state1 = get_agent_state(state, '1')
# state2 = get_agent_state(state, '2')
# ```
#
# Oba sposoby działają identycznie - funkcja `get_agent_state()` jest wrapperem dla `env.get_agent_state()`.

# %% [markdown]
# ## ✅ Podsumowanie zmian - Integracja między plikami
#
# ### 🔧 **Zmiany w `treasure_env.py`:**
# - ✅ Dodana metoda `get_agent_state(state, agent_id)` do klasy `MultiTreasureHunterMDP`
# - ✅ Metoda przekształca stan globalny na stan z perspektywy agenta
#
# ### 🎮 **Zmiany w `game_active.py`:**
# - ✅ Dodana funkcja `play_and_train_multi()` z parametrem `use_agent_perspective`
# - ✅ Zaktualizowana funkcja `test_policy_animated()` z parametrem `use_agent_perspective`
# - ✅ Obie funkcje używają `env.get_agent_state()` do transformacji stanu
#
# ### 📓 **Zmiany w notebooku `treasuerHunter_active.ipynb`:**
# - ✅ Dodana metoda `get_agent_state()` do klasy środowiska w notebooku
# - ✅ Dodana funkcja pomocnicza `get_agent_state()` (wrapper dla kompatybilności)
# - ✅ Funkcje `play_and_train_multi()` i `test_policy()` używają transformacji stanu
#
# ### 🎯 **Rezultat:**
# Wszystkie pliki są teraz **w pełni kompatybilne** i używają tej samej logiki transformacji stanu z perspektywy agenta!

# %% [markdown]
# # Środowisko

# %%
LEFT, DOWN, RIGHT, UP = 0, 1, 2, 3
ACTIONS = [(-1, 0), (0, 1), (1, 0), (0, -1)]

class MultiTreasureHunterMDP:
    def __init__(self, map_lines):
        self.original_map = [list(row) for row in map_lines]
        self.height = len(self.original_map)
        self.width = len(self.original_map[0])
        self.treasures = set()
        self.bases = {}
        self.agent_pos = {}
        self.agent_holding = {'1': False, '2': False}
        self.agent_score = {'1': 0, '2': 0}
        self.winning_score = len([tile for row in self.original_map for tile in row if tile == 'T']) // 2 + 1

    def reset(self):
        self.map = [row[:] for row in self.original_map]
        self.treasures = set()
        self.bases = {}
        self.agent_holding = {'1': False, '2': False}
        self.agent_score = {'1': 0, '2': 0}

        for y in range(self.height):
            for x in range(self.width):
                tile = self.map[y][x]
                if tile == 'T':
                    self.treasures.add((x, y))
                elif tile == 'A':
                    self.bases['1'] = (x, y)
                    self.map[y][x] = '.'
                elif tile == 'B':
                    self.bases['2'] = (x, y)
                    self.map[y][x] = '.'

        self.agent_pos['1'] = self.bases['1']
        self.agent_pos['2'] = self.bases['2']

        return self._get_state()

    def _get_state(self):
        return (
            self.agent_pos['1'],
            self.agent_pos['2'],
            frozenset(self.treasures),
            self.agent_holding['1'],
            self.agent_holding['2']
        )
    
    def get_agent_state(self, state, agent_id):
        pos1, pos2, treasures, hold1, hold2 = state
        
        if agent_id == '1':
            return (pos1, pos2, treasures, hold1, hold2)
        else:
            return (pos2, pos1, treasures, hold2, hold1)

    def get_possible_actions(self, state=None, agent_id='1'):
        if state is None:
            return [LEFT, DOWN, RIGHT, UP]
        
        pos1, pos2, _, _, _ = state
        agent_pos = pos1 if agent_id == '1' else pos2
        x, y = agent_pos
        
        possible_actions = []
        for action in [LEFT, DOWN, RIGHT, UP]:
            _x, _y = ACTIONS[action]
            new_x, new_y = x + _x, y + _y
            
            if 0 <= new_x < self.width and 0 <= new_y < self.height:
                if self.map[new_y][new_x] != '#':
                    possible_actions.append(action)
        
        return possible_actions

    def _move(self, agent_id, action):
        x, y = self.agent_pos[agent_id]
        _x, _y = ACTIONS[action]
        new_x, new_y = x + _x, y + _y

        if not (0 <= new_x < self.width and 0 <= new_y < self.height):
            return x, y
        if self.map[new_y][new_x] == '#':
            return x, y
        
        other_pos = self.agent_pos['2'] if agent_id == '1' else self.agent_pos['1']
        if (new_x, new_y) == other_pos:
            return x, y

        return new_x, new_y

    def step(self, action1, action2):
        rewards = {'1': 0.0, '2': 0.0}
        info = {}

        prev_pos1 = self.agent_pos['1']
        prev_pos2 = self.agent_pos['2']

        self.agent_pos['1'] = self._move('1', action1)
        self.agent_pos['2'] = self._move('2', action2)
        rewards['1'] -= 1
        rewards['2'] -= 1

        if self.agent_pos['1'] == self.agent_pos['2']:
            collision_pos = self.agent_pos['1']
            
            if self.agent_holding['1']:
                self.treasures.add(prev_pos1)
                self.agent_holding['1'] = False
                info['1_drop_collision'] = True
            
            if self.agent_holding['2']:
                self.treasures.add(prev_pos2)
                self.agent_holding['2'] = False
                info['2_drop_collision'] = True
            
            self.agent_pos['1'] = self.bases['1']
            self.agent_pos['2'] = self.bases['2']
            
            rewards['1'] -= 10
            rewards['2'] -= 10
            info['collision'] = True

        for agent_id, pos, prev_pos in [('1', self.agent_pos['1'], prev_pos1), ('2', self.agent_pos['2'], prev_pos2)]:
            x, y = pos

            if self.map[y][x] == 'H':
                if self.agent_holding[agent_id]:
                    self.treasures.add(prev_pos)
                    self.agent_holding[agent_id] = False
                    info[f'{agent_id}_drop_trap'] = True
                
                self.agent_pos[agent_id] = self.bases[agent_id]
                rewards[agent_id] = -30
                info[f'{agent_id}_trap'] = True
                continue

            if pos in self.treasures and not self.agent_holding[agent_id]:
                self.treasures.remove(pos)
                self.agent_holding[agent_id] = True
                rewards[agent_id] += 2
                info[f'{agent_id}_pick'] = True

            if pos == self.bases[agent_id] and self.agent_holding[agent_id]:
                self.agent_holding[agent_id] = False
                self.agent_score[agent_id] += 1  
                rewards[agent_id] += 5 
                info[f'{agent_id}_deposit'] = True

        done = self._is_done()
        return self._get_state(), rewards, done, info

    def _is_done(self):
        # check_trap1 = self.map[self.agent_pos['1'][1]][self.agent_pos['1'][0]] == 'H'
        # check_trap2 = self.map[self.agent_pos['2'][1]][self.agent_pos['2'][0]] == 'H'

        if self.agent_score['1'] == self.winning_score or self.agent_score['2'] == self.winning_score:
            return True

        check_treasure = len(self.treasures) == 0

        check_both_home = (
            self.agent_pos['1'] == self.bases['1'] and
            self.agent_pos['2'] == self.bases['2'] and
            not self.agent_holding['1'] and not self.agent_holding['2']
        )
        # return (check_trap1 and check_trap2) or (check_treasure and check_both_home)
        return check_treasure and check_both_home

    def render(self):
        pass
        # grid = [row[:] for row in self.map]
        # for x, y in self.treasures:
        #     grid[y][x] = 'T'
        # p1, p2 = self.agent_pos['1'], self.agent_pos['2']
        # grid[p1[1]][p1[0]] = if self.agent_holding['1'] else '1'
        # grid[p2[1]][p2[0]] = if self.agent_holding['2'] else '2'

        # print("\n" + "="*40)
        # for row in grid:
        #     print(''.join(row))
        # print(f"Skarby: {len(self.treasures)} | Punkty: 1:{self.agent_score['1']}  2:{self.agent_score['2']}")
        # print(f"Trzyma: 1:{self.agent_holding['1']}  2:{self.agent_holding['2']}")
        # print("="*40)

# %%
import random
from collections import defaultdict


class DQLearningAgent:
    def __init__(self, alpha, epsilon, discount, get_legal_actions):
        """
        Double Q-Learning Agent
        based on https://inst.eecs.berkeley.edu/~cs188/sp19/projects.html
        Instance variables you have access to
          - self.epsilon (exploration prob)
          - self.alpha (learning rate)
          - self.discount (discount rate aka gamma)
        """

        self.get_legal_actions = get_legal_actions
        self._qvaluesA = defaultdict(lambda: defaultdict(lambda: 0))
        self._qvaluesB = defaultdict(lambda: defaultdict(lambda: 0))
        self.alpha = alpha
        self.epsilon = epsilon
        self.discount = discount
        
    def get_qvalue(self, state, action):
        """ Returns Q(state,action) """
        return self._qvaluesA[state][action] + self._qvaluesB[state][action] 


    #---------------------START OF YOUR CODE---------------------#

    def get_best_action(self, state, table='A'):
        """
        Compute the best action to take in a state (using current q-values).
        """
        possible_actions = self.get_legal_actions(state)

        # If there are no legal actions, return None
        if len(possible_actions) == 0:
            return None
        
        possible_actions_values = {}
        for a in possible_actions:
            if table == 'A':
                possible_actions_values[a] = self._qvaluesA[state][a]
            else:
                possible_actions_values[a] = self._qvaluesB[state][a]
            # possible_actions_values[a] = self.get_qvalue(state, a)

        max_qvalue = max(possible_actions_values.values())
        
        # wybierz najlepszą akcję losowo (jesli jest jedna to tą jedną)
        best_action = random.choice([a for a, v in possible_actions_values.items() if v == max_qvalue])
        
        return best_action

    def update(self, state, action, reward, next_state):
        """
        You should do your Q-Value update here
        """

        # agent parameters
        gamma = self.discount
        learning_rate = self.alpha

        # curr_qvalue = self.get_qvalue(state, action)
        # next_action = self.get_best_action(next_state,)

        p = random.uniform(0, 1)
        if p < 0.5:
            next_action = self.get_best_action(next_state, table='A')
            next_qvalue = self._qvaluesB[next_state][next_action]
            
            res = learning_rate * (reward + gamma * next_qvalue - self._qvaluesA[state][action])
            self._qvaluesA[state][action] += res
        else:
            next_action = self.get_best_action(next_state, table='B')
            next_qvalue = self._qvaluesA[next_state][next_action]
            
            res = learning_rate * (reward + gamma * next_qvalue - self._qvaluesB[state][action])
            self._qvaluesB[state][action] += res
        
        return self.get_best_action(next_state)


    def get_action(self, state):
        """
        Compute the action to take in the current state, including exploration.
        With probability self.epsilon, we should take a random action.
            otherwise - the best policy action (self.get_best_action).

        Note: To pick randomly from a list, use random.choice(list).
              To pick True or False with a given probablity, generate uniform number in [0, 1]
              and compare it with your probability
        """

        # Pick Action
        possible_actions = self.get_legal_actions(state)

        # If there are no legal actions, return None
        if len(possible_actions) == 0:
            return None

        # agent parameters:
        epsilon = self.epsilon

        p = random.uniform(0, 1)
        if p < epsilon:  # eksploracja z prawdopodobieństwem epsilon
            chosen_action = random.choice(possible_actions)
        else:  # eksploatacja (najlepsza akcja) z prawdopodobieństwem 1-epsilon
            chosen_action = self.get_best_action(state)        

        return chosen_action

    def reset(self):
        pass

    def turn_off_learning(self):
        self.epsilon = 0
        self.alpha = 0

# %%
import random
from collections import defaultdict


class SARSALambdaAgent:
    def __init__(self, alpha, epsilon, discount, get_legal_actions, lambda_value):
        """
        SARSA Lambda Agent
        based on https://inst.eecs.berkeley.edu/~cs188/sp19/projects.html
        Instance variables you have access to
          - self.epsilon (exploration prob)
          - self.alpha (learning rate)
          - self.discount (discount rate aka gamma)

        Functions you should use
          - self.get_legal_actions(state) {state, hashable -> list of actions, each is hashable}
            which returns legal actions for a state
          - self.get_qvalue(state,action)
            which returns Q(state,action)
          - self.set_qvalue(state,action,value)
            which sets Q(state,action) := value
        # !!!Important!!!
        Note: please avoid using self._qValues directly.
            There's a special self.get_qvalue/set_qvalue for that.
        """

        self.get_legal_actions = get_legal_actions
        self._qvalues = defaultdict(lambda: defaultdict(lambda: 0))
        self._evalues = defaultdict(lambda: defaultdict(lambda: 0))
        self.alpha = alpha
        self.epsilon = epsilon
        self.discount = discount
        self.lambda_value = lambda_value

    def get_qvalue(self, state, action):
        """ Returns Q(state,action) """
        return self._qvalues[state][action]

    def set_qvalue(self, state, action, value):
        """ Sets the Qvalue for [state,action] to the given value """
        self._qvalues[state][action] = value

    def reset(self):
        self._evalues = defaultdict(lambda: defaultdict(lambda: 0))

    # ---------------------START OF YOUR CODE---------------------#

    def get_value(self, state):
        """
        Compute your agent's estimate of V(s) using current q-values
        V(s) = max_over_action Q(state,action) over possible actions.
        Note: please take into account that q-values can be negative.
        """
        possible_actions = self.get_legal_actions(state)

        # If there are no legal actions, return 0.0
        if len(possible_actions) == 0:
            return 0.0
        
        values = []
        for a in possible_actions:
            values.append(self.get_qvalue(state, a))


        return max(values)

    def update(self, state, action, reward, next_state):
        """
        You should do your SARSA-Lambda update here:
        """

        # agent parameters
        gamma = self.discount
        learning_rate = self.alpha

        curr_qvalue = self.get_qvalue(state, action)
        next_action = self.get_best_action(next_state)
        next_qvalue = self.get_qvalue(next_state, next_action)

        sigma = reward + gamma * next_qvalue - curr_qvalue
        self._evalues[state][action] = 1
        for s in self._evalues:
            for a in self._evalues[s]:
                old_qvalue = self.get_qvalue(s, a)

                res = old_qvalue + learning_rate * sigma * self._evalues[s][a]
                self.set_qvalue(s, a, res)
                self._evalues[s][a] = gamma * self.lambda_value * self._evalues[s][a]

        return next_action

    def get_best_action(self, state):
        """
        Compute the best action to take in a state (using current q-values).
        """
        possible_actions = self.get_legal_actions(state)

        # If there are no legal actions, return None
        if len(possible_actions) == 0:
            return None

        possible_actions_values = {}
        for a in possible_actions:
            possible_actions_values[a] = self.get_qvalue(state, a)

        max_qvalue = max(possible_actions_values.values())

        best_action = random.choice([a for a, value in possible_actions_values.items() if value == max_qvalue])

        return best_action

    def get_action(self, state):
        """
        Compute the action to take in the current state, including exploration.
        With probability self.epsilon, we should take a random action.
            otherwise - the best policy action (self.get_best_action).

        Note: To pick randomly from a list, use random.choice(list).
              To pick True or False with a given probablity, generate uniform number in [0, 1]
              and compare it with your probability
        """

        # Pick Action
        possible_actions = self.get_legal_actions(state)

        # If there are no legal actions, return None
        if len(possible_actions) == 0:
            return None

        # agent parameters:
        epsilon = self.epsilon

        p = random.uniform(0, 1)
        if p < epsilon:  # eksploracja z prawdopodobieństwem epsilon
            chosen_action = random.choice(possible_actions)
        else:  # eksploatacja (najlepsza akcja) z prawdopodobieństwem 1-epsilon
            chosen_action = self.get_best_action(state)    

        return chosen_action

    def turn_off_learning(self):
        self.epsilon = 0
        self.alpha = 0

    def display_qvalues(self):
        for s in self._qvalues:
            print("State: " + str(s) + " " + str(self._qvalues[s]))

# %%
def play_and_train_multi(env, agent1, agent2, episodes=5000, use_agent_perspective=True):
    rewards_history_agent1 = []
    rewards_history_agent2 = []
    scores_history_agent1 = []
    scores_history_agent2 = []

    for ep in range(episodes):
        state = env.reset()
        total_r1 = total_r2 = 0
        agent1.reset()
        agent2.reset()

        # Przekształć stan dla każdego agenta
        if use_agent_perspective:
            state1 = env.get_agent_state(state, '1')
            state2 = env.get_agent_state(state, '2')
        else:
            state1 = state2 = state
        
        action1 = agent1.get_action(state1)
        action2 = agent2.get_action(state2)

        while True:
            next_state, rewards, done, _ = env.step(action1, action2)
            r1, r2 = rewards['1'], rewards['2']
            total_r1 += r1
            total_r2 += r2

            if use_agent_perspective:
                next_state1 = env.get_agent_state(next_state, '1')
                next_state2 = env.get_agent_state(next_state, '2')
            else:
                next_state1 = next_state2 = next_state

            next_action1 = agent1.update(state1, action1, r1, next_state1)
            next_action2 = agent2.update(state2, action2, r2, next_state2)

            action1 = next_action1 if next_action1 is not None else agent1.get_action(next_state1)
            action2 = next_action2 if next_action2 is not None else agent2.get_action(next_state2)
            
            state1 = next_state1
            state2 = next_state2
            state = next_state

            if done:
                break

        score1 = env.agent_score['1']
        score2 = env.agent_score['2']
        
        rewards_history_agent1.append(total_r1)
        rewards_history_agent2.append(total_r2)
        scores_history_agent1.append(score1)
        scores_history_agent2.append(score2)

        if (ep + 1) % 100 == 0:
            print(f"Epizod {ep+1:4d} | Agent1: R={total_r1:6.1f} P={score1} | Agent2: R={total_r2:6.1f} P={score2}")

    return (rewards_history_agent1, rewards_history_agent2, 
            scores_history_agent1, scores_history_agent2)

# %%
import time

def test_policy(env, agent1, agent2, episodes=3, delay=0.3, max_steps=100, use_agent_perspective=True):
    """
        use_agent_perspective: ustaw na True, wtedy agent dostaje stan ze swojej perspektywy
    """
    agent1.turn_off_learning()
    agent2.turn_off_learning()
    
    action_names = {
        0: '<< LEWO',
        1: '\/ DÓŁ',
        2: '>> PRAWO',
        3: '/\ GÓRA'
    }

    for ep in range(episodes):
        state = env.reset()
        print(f"\n{'='*50}")
        print(f"GRA TESTOWA {ep+1}")
        print(f"{'='*50}")
        step = 0

        while step < max_steps:
            if use_agent_perspective:
                state1 = env.get_agent_state(state, '1')
                state2 = env.get_agent_state(state, '2')
            else:
                state1 = state2 = state
            
            a1 = agent1.get_action(state1)
            a2 = agent2.get_action(state2)
            state, rewards, done, info = env.step(a1, a2)
            step += 1
            
            events = []
            if '1_pick' in info:
                events.append("T: A1")
            if '2_pick' in info:
                events.append("T: A2")
            if '1_deposit' in info:
                events.append("[H]: A1")
            if '2_deposit' in info:
                events.append("[H]: A2")
            
            event_str = " " + " ".join(events) if events else ""
            print(f"Krok {step:2d}: A1={action_names[a1]}, A2={action_names[a2]} | R1={rewards['1']:+.0f} R2={rewards['2']:+.0f}{event_str}")
            
            time.sleep(delay)
            
            if done:
                print(f"\n{'='*50}")
                print(f"🏁 KONIEC GRY {ep+1} (w {step} krokach)")
                score1 = env.agent_score['1']
                score2 = env.agent_score['2']
                print(f"Wynik końcowy:")
                print(f"  Agent 1 (SARSA-λ): {score1} punktów")
                print(f"  Agent 2 (Double-Q): {score2} punktów")
                
                if score1 > score2:
                    print(f"\nWYGRYWA Agent 1 z przewagą {score1 - score2} punktów!")
                elif score2 > score1:
                    print(f"\nWYGRYWA Agent 2 z przewagą {score2 - score1} punktów!")
                else:
                    print(f"\nREMIS! Obaj agenci zdobyli {score1} punktów!")
                print(f"{'='*50}")
                break
        
        if step >= max_steps:
            print(f"\nPRZERWANO - osiągnięto limit {max_steps} kroków!")
            print(f"Punkty: A1={env.agent_score['1']}, A2={env.agent_score['2']}")
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\/'
# <>:14: SyntaxWarning: invalid escape sequence '\ '
# <>:12: SyntaxWarning: invalid escape sequence '\/'
# <>:14: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\jasin\AppData\Local\Temp\ipykernel_21188\2208589399.py:12: SyntaxWarning: invalid escape sequence '\/'
#   1: '\/ DÓŁ',
# C:\Users\jasin\AppData\Local\Temp\ipykernel_21188\2208589399.py:14: SyntaxWarning: invalid escape sequence '\ '
#   3: '/\ GÓRA'

# %%
MAP1 = [
    "A....T....",
    "..#..#..#.",
    "T.......H.",
    "..#..T..#.",
    "....H....B"
]

MAP2 = [
    "A........T",
    "..#..#..#.",
    ".H..T...H.",
    ".#..#..#..",
    "T........B"
]

MAP3 = [
    "A....H...T",
    ".#.#....#.",
    ".H.#T..#H.",
    "..#...H.#.",
    "T...H....B"
]

# %%
import importlib
import agents
importlib.reload(agents)
from agents import QLearningAgent, SARSAAgent, ExpectedSARSAAgent
SAVE_AGENTS = True

# %%
env2 = MultiTreasureHunterMDP(MAP3)
state2 = env2.reset()

# Agent 3: SARSA
agent3 = SARSAAgent(
    alpha=0.1, epsilon=0.15, discount=0.9,
    get_legal_actions=lambda s: env2.get_possible_actions(s, agent_id='1')
)

# Agent 4: Q-Learning
agent4 = QLearningAgent(
    alpha=0.1, epsilon=0.15, discount=0.9,
    get_legal_actions=lambda s: env2.get_possible_actions(s, agent_id='2')
)

print("\nTrening agentów (Q-Learning vs SARSA):")
rewards3, rewards4, scores3, scores4 = play_and_train_multi(env2, agent3, agent4, episodes=10000)

print(f"\nAgent 3 (Q-Learning) zna {len(agent3._qvalues)} stanów")
print(f"Agent 4 (SARSA) zna {len(agent4._qvalues)} stanów")

# Wykresy porównawcze
plt.figure(figsize=(14, 10))

# Nagrody agentów
plt.subplot(2, 2, 1)
plt.plot(rewards3, label='Agent 3 (Q-Learning)', alpha=0.7, color='green')
plt.plot(rewards4, label='Agent 4 (SARSA)', alpha=0.7, color='orange')
plt.title("Nagrody na epizod")
plt.xlabel("Epizod")
plt.ylabel("Nagroda")
plt.legend()
plt.grid(True)

# Punkty (zebrane skarby) agentów
plt.subplot(2, 2, 2)
plt.plot(scores3, label='Agent 3 (Q-Learning)', color='green', alpha=0.7)
plt.plot(scores4, label='Agent 4 (SARSA)', color='orange', alpha=0.7)
plt.title("Zebrane skarby (punkty)")
plt.xlabel("Epizod")
plt.ylabel("Punkty")
plt.legend()
plt.grid(True)

# Średnie kroczące nagród (100 epizodów)
plt.subplot(2, 2, 3)
window = 100
if len(rewards3) >= window:
    avg_r3 = np.convolve(rewards3, np.ones(window)/window, mode='valid')
    avg_r4 = np.convolve(rewards4, np.ones(window)/window, mode='valid')
    plt.plot(avg_r3, label='Agent 3 (średnia)', linewidth=2, color='green')
    plt.plot(avg_r4, label='Agent 4 (średnia)', linewidth=2, color='orange')
    plt.title(f"Średnia krocząca nagród ({window} epizodów)")
    plt.xlabel("Epizod")
    plt.ylabel("Średnia nagroda")
    plt.legend()
    plt.grid(True)

# Porównanie całkowitych punktów
plt.subplot(2, 2, 4)
total_scores3 = sum(scores3)
total_scores4 = sum(scores4)
plt.bar(['Agent 3\n(Q-Learning)', 'Agent 4\n(SARSA)'], 
        [total_scores3, total_scores4], 
        color=['green', 'orange'], alpha=0.7)
plt.title("Łączna liczba zebranych skarbów")
plt.ylabel("Suma punktów")
plt.grid(True, axis='y')

plt.tight_layout()
plt.show()

print(f"Agent 3 (Q-Learning): Łącznie punktów: {total_scores3}, Średnia nagroda: {np.mean(rewards3):.1f}")
print(f"Agent 4 (SARSA):      Łącznie punktów: {total_scores4}, Średnia nagroda: {np.mean(rewards4):.1f}")

print("\n=== TESTOWANIE WYTRENOWANEJ POLITYKI (Q-Learning vs SARSA) ===")
test_policy(env2, agent3, agent4, episodes=1, delay=0.3)
# Out:
# Trening agentów (Q-Learning vs SARSA):
# Epizod  100 | Agent1: R=-3943.0 P=2 | Agent2: R=-3118.0 P=1
# Epizod  100 | Agent1: R=-3943.0 P=2 | Agent2: R=-3118.0 P=1
# Epizod  200 | Agent1: R= -40.0 P=2 | Agent2: R= -47.0 P=1
# Epizod  200 | Agent1: R= -40.0 P=2 | Agent2: R= -47.0 P=1
# Epizod  300 | Agent1: R= -20.0 P=2 | Agent2: R= -56.0 P=1
# Epizod  400 | Agent1: R= -56.0 P=2 | Agent2: R= -63.0 P=1
# Epizod  300 | Agent1: R= -20.0 P=2 | Agent2: R= -56.0 P=1
# Epizod  400 | Agent1: R= -56.0 P=2 | Agent2: R= -63.0 P=1
# Epizod  500 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod  600 | Agent1: R= -12.0 P=2 | Agent2: R= -48.0 P=1
# Epizod  500 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod  600 | Agent1: R= -12.0 P=2 | Agent2: R= -48.0 P=1
# Epizod  700 | Agent1: R=-364.0 P=2 | Agent2: R=-284.0 P=1
# Epizod  800 | Agent1: R=-375.0 P=0 | Agent2: R=-367.0 P=2
# Epizod  700 | Agent1: R=-364.0 P=2 | Agent2: R=-284.0 P=1
# Epizod  800 | Agent1: R=-375.0 P=0 | Agent2: R=-367.0 P=2
# Epizod  900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1000 | Agent1: R=-278.0 P=2 | Agent2: R=-202.0 P=1
# Epizod  900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1000 | Agent1: R=-278.0 P=2 | Agent2: R=-202.0 P=1
# Epizod 1100 | Agent1: R=-673.0 P=1 | Agent2: R=-563.0 P=1
# Epizod 1200 | Agent1: R= -32.0 P=2 | Agent2: R= -68.0 P=1
# Epizod 1300 | Agent1: R=-114.0 P=2 | Agent2: R= -94.0 P=1
# Epizod 1100 | Agent1: R=-673.0 P=1 | Agent2: R=-563.0 P=1
# Epizod 1200 | Agent1: R= -32.0 P=2 | Agent2: R= -68.0 P=1
# Epizod 1300 | Agent1: R=-114.0 P=2 | Agent2: R= -94.0 P=1
# Epizod 1400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1500 | Agent1: R= -16.0 P=2 | Agent2: R= -52.0 P=1
# Epizod 1600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1500 | Agent1: R= -16.0 P=2 | Agent2: R= -52.0 P=1
# Epizod 1600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1900 | Agent1: R=-103.0 P=2 | Agent2: R=-139.0 P=1
# Epizod 2000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2100 | Agent1: R=-176.0 P=2 | Agent2: R=-210.0 P=1
# Epizod 1900 | Agent1: R=-103.0 P=2 | Agent2: R=-139.0 P=1
# Epizod 2000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2100 | Agent1: R=-176.0 P=2 | Agent2: R=-210.0 P=1
# Epizod 2200 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 2300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2200 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 2300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2500 | Agent1: R=-339.0 P=2 | Agent2: R=-377.0 P=1
# Epizod 2600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2800 | Agent1: R= -12.0 P=2 | Agent2: R= -48.0 P=1
# Epizod 2500 | Agent1: R=-339.0 P=2 | Agent2: R=-377.0 P=1
# Epizod 2600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2800 | Agent1: R= -12.0 P=2 | Agent2: R= -48.0 P=1
# Epizod 2900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3200 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 3300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3200 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 3300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3400 | Agent1: R=-220.0 P=1 | Agent2: R=-182.0 P=2
# Epizod 3500 | Agent1: R=-203.0 P=2 | Agent2: R=-248.0 P=0
# Epizod 3600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3400 | Agent1: R=-220.0 P=1 | Agent2: R=-182.0 P=2
# Epizod 3500 | Agent1: R=-203.0 P=2 | Agent2: R=-248.0 P=0
# Epizod 3600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5200 | Agent1: R=-577.0 P=0 | Agent2: R=-362.0 P=2
# Epizod 5300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5200 | Agent1: R=-577.0 P=0 | Agent2: R=-362.0 P=2
# Epizod 5300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5400 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 5500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5400 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 5500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5900 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 6000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6500 | Agent1: R= -64.0 P=2 | Agent2: R=-136.0 P=0
# Epizod 6600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5900 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 6000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6500 | Agent1: R= -64.0 P=2 | Agent2: R=-136.0 P=0
# Epizod 6600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7200 | Agent1: R=  -6.0 P=2 | Agent2: R= -42.0 P=1
# Epizod 6700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7200 | Agent1: R=  -6.0 P=2 | Agent2: R= -42.0 P=1
# Epizod 7300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 7900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8600 | Agent1: R=-306.0 P=2 | Agent2: R=-402.0 P=1
# Epizod 8700 | Agent1: R=-432.0 P=2 | Agent2: R=-617.0 P=1
# Epizod 8200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8600 | Agent1: R=-306.0 P=2 | Agent2: R=-402.0 P=1
# Epizod 8700 | Agent1: R=-432.0 P=2 | Agent2: R=-617.0 P=1
# Epizod 8800 | Agent1: R= -61.0 P=2 | Agent2: R= -44.0 P=0
# Epizod 8900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9100 | Agent1: R=  -6.0 P=2 | Agent2: R= -42.0 P=1
# Epizod 9200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 8800 | Agent1: R= -61.0 P=2 | Agent2: R= -44.0 P=0
# Epizod 8900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9100 | Agent1: R=  -6.0 P=2 | Agent2: R= -42.0 P=1
# Epizod 9200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9700 | Agent1: R=  -6.0 P=2 | Agent2: R= -42.0 P=1
# Epizod 9800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 10000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
#
# Agent 3 (Q-Learning) zna 62573 stanów
# Agent 4 (SARSA) zna 62573 stanów
# Epizod 9600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9700 | Agent1: R=  -6.0 P=2 | Agent2: R= -42.0 P=1
# Epizod 9800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 10000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
#
# Agent 3 (Q-Learning) zna 62573 stanów
# Agent 4 (SARSA) zna 62573 stanów
# Agent 3 (Q-Learning): Łącznie punktów: 19278, Średnia nagroda: -81.8
# Agent 4 (SARSA):      Łącznie punktów: 9927, Średnia nagroda: -79.6
#
# === TESTOWANIE WYTRENOWANEJ POLITYKI (Q-Learning vs SARSA) ===
#
# ==================================================
# GRA TESTOWA 1
# ==================================================
# Krok  1: A1=\/ DÓŁ, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  2: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  2: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  3: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  3: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  4: A1=\/ DÓŁ, A2=/\ GÓRA | R1=+1 R2=-1 T: A1
# Krok  4: A1=\/ DÓŁ, A2=/\ GÓRA | R1=+1 R2=-1 T: A1
# Krok  5: A1=/\ GÓRA, A2=/\ GÓRA | R1=-1 R2=+1 T: A2
# Krok  5: A1=/\ GÓRA, A2=/\ GÓRA | R1=-1 R2=+1 T: A2
# Krok  6: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  6: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  7: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  7: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  8: A1=/\ GÓRA, A2=\/ DÓŁ | R1=+4 R2=-1 [H]: A1
# Krok  8: A1=/\ GÓRA, A2=\/ DÓŁ | R1=+4 R2=-1 [H]: A1
# Krok  9: A1=>> PRAWO, A2=\/ DÓŁ | R1=-1 R2=+4 [H]: A2
# Krok  9: A1=>> PRAWO, A2=\/ DÓŁ | R1=-1 R2=+4 [H]: A2
# Krok 10: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 10: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 11: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 11: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 12: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 12: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 13: A1=\/ DÓŁ, A2=<< LEWO | R1=-1 R2=-1
# Krok 13: A1=\/ DÓŁ, A2=<< LEWO | R1=-1 R2=-1
# Krok 14: A1=\/ DÓŁ, A2=\/ DÓŁ | R1=+1 R2=-1 T: A1
# Krok 14: A1=\/ DÓŁ, A2=\/ DÓŁ | R1=+1 R2=-1 T: A1
# Krok 15: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 15: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 16: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 16: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 17: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 17: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 18: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 18: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 19: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 19: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 20: A1=<< LEWO, A2=>> PRAWO | R1=+4 R2=-1 [H]: A1
# Krok 20: A1=<< LEWO, A2=>> PRAWO | R1=+4 R2=-1 [H]: A1
#
# ==================================================
# 🏁 KONIEC GRY 1 (w 20 krokach)
# Wynik końcowy:
#   Agent 1 (SARSA-λ): 2 punktów
#   Agent 2 (Double-Q): 1 punktów
#
# WYGRYWA Agent 1 z przewagą 1 punktów!
# ==================================================
#
# ==================================================
# 🏁 KONIEC GRY 1 (w 20 krokach)
# Wynik końcowy:
#   Agent 1 (SARSA-λ): 2 punktów
#   Agent 2 (Double-Q): 1 punktów
#
# WYGRYWA Agent 1 z przewagą 1 punktów!
# ==================================================

# %%
if SAVE_AGENTS:
    try:
        import dill
    except ImportError:
        import subprocess
        import sys
        subprocess.check_call([sys.executable, "-m", "pip", "install", "dill"])
        import dill

    import os

    # Zapisz obu agentów do jednego pliku jako słownik
    agents_dict = {
        'agent1': agent3,
        'agent2': agent4,
        'description': 'SARSA vs Q-Learning'
    }

    with open('agents_SARSA_vs_QLearning.pkl', 'wb') as f:
        dill.dump(agents_dict, f)
    print("[OK] Agenci zapisani jako: agents_SARSA_vs_QLearning.pkl")

    # Pokaz statystyki
    print("\n=== Statystyki zapisanych agentow ===")
    print(f"Agent 1 (SARSA):      {len(agent3._qvalues)} znanych stanow")
    print(f"Agent 2 (Q-Learning): {len(agent4._qvalues)} znanych stanow")

    print("\n[>] Pliki zapisane w folderze:")
    print(f"    {os.path.abspath('.')}")
    print("\n[>] Teraz mozesz uruchomic:")
    print("    python test_game.py")
# Out:
# [OK] Agenci zapisani jako: agents_SARSA_vs_QLearning.pkl
#
# === Statystyki zapisanych agentow ===
# Agent 1 (SARSA):      62573 znanych stanow
# Agent 2 (Q-Learning): 62573 znanych stanow
#
# [>] Pliki zapisane w folderze:
#     c:\Users\jasin\.Astudia\ucz_ze_wzmoc\treasurerEnv
#
# [>] Teraz mozesz uruchomic:
#     python test_game.py

# %% [markdown]
# ### QLearning vs ExpectedSARSA:

# %%
import matplotlib.pyplot as plt
env3 = MultiTreasureHunterMDP(MAP3)
state3 = env3.reset()

agent5 = QLearningAgent(
    alpha=0.1, epsilon=0.15, discount=0.9,
    get_legal_actions=lambda s: env3.get_possible_actions(s, agent_id='1')
)

agent6 = ExpectedSARSAAgent(
    alpha=0.1, epsilon=0.15, discount=0.9,
    get_legal_actions=lambda s: env3.get_possible_actions(s, agent_id='2')
)

print("\nTrening agentów (Q-Learning vs ExpectedSARSA):")
rewards5, rewards6, scores5, scores6 = play_and_train_multi(env3, agent5, agent6, episodes=10000)

print(f"\nAgent 5 (Q-Learning) zna {len(agent5._qvalues)} stanów")
print(f"Agent 6 (ExpectedSARSA) zna {len(agent6._qvalues)} stanów")

# Wykresy porównawcze
plt.figure(figsize=(14, 10))

# Nagrody agentów
plt.subplot(2, 2, 1)
plt.plot(rewards5, label='Agent 5 (ExpectedSARSA)', alpha=0.7, color='green')
plt.plot(rewards6, label='Agent 6 (Q-Learning)', alpha=0.7, color='orange')
plt.title("Nagrody na epizod")
plt.xlabel("Epizod")
plt.ylabel("Nagroda")
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(scores5, label='Agent 5 (QLearning)', color='green', alpha=0.7)
plt.plot(scores6, label='Agent 6 (ExpectedSARSA)', color='orange', alpha=0.7)
plt.title("Zebrane skarby (punkty)")
plt.xlabel("Epizod")
plt.ylabel("Punkty")
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
window = 100
if len(rewards5) >= window:
    avg_r5 = np.convolve(rewards5, np.ones(window)/window, mode='valid')
    avg_r6 = np.convolve(rewards6, np.ones(window)/window, mode='valid')
    plt.plot(avg_r5, label='Agent 5 (średnia)', linewidth=2, color='green')
    plt.plot(avg_r6, label='Agent 6 (średnia)', linewidth=2, color='orange')
    plt.title(f"Średnia krocząca nagród ({window} epizodów)")
    plt.xlabel("Epizod")
    plt.ylabel("Średnia nagroda")
    plt.legend()
    plt.grid(True)

plt.subplot(2, 2, 4)
total_scores5 = sum(scores5)
total_scores6 = sum(scores6)
plt.bar(['Agent 5\n(QLearning)', 'Agent 6\n(ExpectedSARSA)'], 
        [total_scores5, total_scores6], 
        color=['green', 'orange'], alpha=0.7)
plt.title("Łączna liczba zebranych skarbów")
plt.ylabel("Suma punktów")
plt.grid(True, axis='y')

plt.tight_layout()
plt.show()

print(f"Agent 5 (QLearning): Łącznie punktów: {total_scores5}, Średnia nagroda: {np.mean(rewards5):.1f}")
print(f"Agent 6 (ExpectedSarsa):      Łącznie punktów: {total_scores6}, Średnia nagroda: {np.mean(rewards6):.1f}")

print("\n=== TESTOWANIE WYTRENOWANEJ POLITYKI (Q-Learning vs ExpectedSARSA) ===")
test_policy(env3, agent5, agent6, episodes=1, delay=0.3)
# Out:
# Trening agentów (Q-Learning vs ExpectedSARSA):
# Epizod  100 | Agent1: R=-408.0 P=2 | Agent2: R=-247.0 P=1
# Epizod  100 | Agent1: R=-408.0 P=2 | Agent2: R=-247.0 P=1
# Epizod  200 | Agent1: R=-129.0 P=2 | Agent2: R=-165.0 P=1
# Epizod  200 | Agent1: R=-129.0 P=2 | Agent2: R=-165.0 P=1
# Epizod  300 | Agent1: R=-120.0 P=2 | Agent2: R=-127.0 P=1
# Epizod  300 | Agent1: R=-120.0 P=2 | Agent2: R=-127.0 P=1
# Epizod  400 | Agent1: R=-199.0 P=2 | Agent2: R=-177.0 P=1
# Epizod  400 | Agent1: R=-199.0 P=2 | Agent2: R=-177.0 P=1
# Epizod  500 | Agent1: R=-163.0 P=2 | Agent2: R=-172.0 P=1
# Epizod  500 | Agent1: R=-163.0 P=2 | Agent2: R=-172.0 P=1
# Epizod  600 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod  600 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod  700 | Agent1: R=-185.0 P=2 | Agent2: R=-250.0 P=1
# Epizod  700 | Agent1: R=-185.0 P=2 | Agent2: R=-250.0 P=1
# Epizod  800 | Agent1: R= -94.0 P=2 | Agent2: R= -72.0 P=1
# Epizod  800 | Agent1: R= -94.0 P=2 | Agent2: R= -72.0 P=1
# Epizod  900 | Agent1: R= -54.0 P=2 | Agent2: R= -34.0 P=1
# Epizod  900 | Agent1: R= -54.0 P=2 | Agent2: R= -34.0 P=1
# Epizod 1000 | Agent1: R=-930.0 P=2 | Agent2: R=-883.0 P=1
# Epizod 1000 | Agent1: R=-930.0 P=2 | Agent2: R=-883.0 P=1
# Epizod 1100 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 1200 | Agent1: R=-651.0 P=0 | Agent2: R=-411.0 P=2
# Epizod 1100 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 1200 | Agent1: R=-651.0 P=0 | Agent2: R=-411.0 P=2
# Epizod 1300 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 1300 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 1400 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 1400 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 1500 | Agent1: R=-202.0 P=1 | Agent2: R=-206.0 P=1
# Epizod 1600 | Agent1: R= -58.0 P=2 | Agent2: R= -65.0 P=1
# Epizod 1500 | Agent1: R=-202.0 P=1 | Agent2: R=-206.0 P=1
# Epizod 1600 | Agent1: R= -58.0 P=2 | Agent2: R= -65.0 P=1
# Epizod 1700 | Agent1: R=-686.0 P=0 | Agent2: R=-475.0 P=2
# Epizod 1700 | Agent1: R=-686.0 P=0 | Agent2: R=-475.0 P=2
# Epizod 1800 | Agent1: R= -18.0 P=2 | Agent2: R= -25.0 P=1
# Epizod 1900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1800 | Agent1: R= -18.0 P=2 | Agent2: R= -25.0 P=1
# Epizod 1900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2000 | Agent1: R= -46.0 P=2 | Agent2: R=-111.0 P=1
# Epizod 2100 | Agent1: R= -20.0 P=2 | Agent2: R= -56.0 P=1
# Epizod 2000 | Agent1: R= -46.0 P=2 | Agent2: R=-111.0 P=1
# Epizod 2100 | Agent1: R= -20.0 P=2 | Agent2: R= -56.0 P=1
# Epizod 2200 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 2200 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 2300 | Agent1: R= -50.0 P=2 | Agent2: R= -55.0 P=1
# Epizod 2300 | Agent1: R= -50.0 P=2 | Agent2: R= -55.0 P=1
# Epizod 2400 | Agent1: R=-709.0 P=0 | Agent2: R=-533.0 P=2
# Epizod 2500 | Agent1: R= -92.0 P=2 | Agent2: R=-128.0 P=1
# Epizod 2400 | Agent1: R=-709.0 P=0 | Agent2: R=-533.0 P=2
# Epizod 2500 | Agent1: R= -92.0 P=2 | Agent2: R=-128.0 P=1
# Epizod 2600 | Agent1: R= -60.0 P=2 | Agent2: R= -40.0 P=1
# Epizod 2700 | Agent1: R= -18.0 P=2 | Agent2: R= -25.0 P=1
# Epizod 2600 | Agent1: R= -60.0 P=2 | Agent2: R= -40.0 P=1
# Epizod 2700 | Agent1: R= -18.0 P=2 | Agent2: R= -25.0 P=1
# Epizod 2800 | Agent1: R= -30.0 P=2 | Agent2: R= -71.0 P=0
# Epizod 2900 | Agent1: R=-106.0 P=2 | Agent2: R= -57.0 P=1
# Epizod 2800 | Agent1: R= -30.0 P=2 | Agent2: R= -71.0 P=0
# Epizod 2900 | Agent1: R=-106.0 P=2 | Agent2: R= -57.0 P=1
# Epizod 3000 | Agent1: R= -28.0 P=2 | Agent2: R= -35.0 P=1
# Epizod 3100 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 3000 | Agent1: R= -28.0 P=2 | Agent2: R= -35.0 P=1
# Epizod 3100 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 3200 | Agent1: R= -24.0 P=2 | Agent2: R= -31.0 P=1
# Epizod 3300 | Agent1: R= -12.0 P=2 | Agent2: R= -55.0 P=0
# Epizod 3200 | Agent1: R= -24.0 P=2 | Agent2: R= -31.0 P=1
# Epizod 3300 | Agent1: R= -12.0 P=2 | Agent2: R= -55.0 P=0
# Epizod 3400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 3500 | Agent1: R=-1004.0 P=1 | Agent2: R=-541.0 P=2
# Epizod 3400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 3500 | Agent1: R=-1004.0 P=1 | Agent2: R=-541.0 P=2
# Epizod 3600 | Agent1: R= -38.0 P=2 | Agent2: R= -16.0 P=1
# Epizod 3700 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 3600 | Agent1: R= -38.0 P=2 | Agent2: R= -16.0 P=1
# Epizod 3700 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 3800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3900 | Agent1: R=-678.0 P=1 | Agent2: R=-383.0 P=2
# Epizod 3800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3900 | Agent1: R=-678.0 P=1 | Agent2: R=-383.0 P=2
# Epizod 4000 | Agent1: R= -78.0 P=2 | Agent2: R= -29.0 P=1
# Epizod 4100 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4000 | Agent1: R= -78.0 P=2 | Agent2: R= -29.0 P=1
# Epizod 4100 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4200 | Agent1: R= -46.0 P=2 | Agent2: R= -24.0 P=1
# Epizod 4300 | Agent1: R= -78.0 P=2 | Agent2: R= -27.0 P=1
# Epizod 4200 | Agent1: R= -46.0 P=2 | Agent2: R= -24.0 P=1
# Epizod 4300 | Agent1: R= -78.0 P=2 | Agent2: R= -27.0 P=1
# Epizod 4400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4500 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4500 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4600 | Agent1: R=-985.0 P=2 | Agent2: R=-758.0 P=0
# Epizod 4700 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4600 | Agent1: R=-985.0 P=2 | Agent2: R=-758.0 P=0
# Epizod 4700 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4900 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4900 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5000 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 5100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5200 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5000 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 5100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5200 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5300 | Agent1: R= -70.0 P=2 | Agent2: R= -23.0 P=1
# Epizod 5400 | Agent1: R=-207.0 P=2 | Agent2: R=-129.0 P=1
# Epizod 5300 | Agent1: R= -70.0 P=2 | Agent2: R= -23.0 P=1
# Epizod 5400 | Agent1: R=-207.0 P=2 | Agent2: R=-129.0 P=1
# Epizod 5500 | Agent1: R= -78.0 P=2 | Agent2: R= -58.0 P=1
# Epizod 5600 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5500 | Agent1: R= -78.0 P=2 | Agent2: R= -58.0 P=1
# Epizod 5600 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5800 | Agent1: R= -16.0 P=2 | Agent2: R= -59.0 P=0
# Epizod 5700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5800 | Agent1: R= -16.0 P=2 | Agent2: R= -59.0 P=0
# Epizod 5900 | Agent1: R= -44.0 P=2 | Agent2: R= -24.0 P=1
# Epizod 6000 | Agent1: R= -12.0 P=2 | Agent2: R= -48.0 P=1
# Epizod 5900 | Agent1: R= -44.0 P=2 | Agent2: R= -24.0 P=1
# Epizod 6000 | Agent1: R= -12.0 P=2 | Agent2: R= -48.0 P=1
# Epizod 6100 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 6200 | Agent1: R=-1000.0 P=1 | Agent2: R=-848.0 P=2
# Epizod 6100 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 6200 | Agent1: R=-1000.0 P=1 | Agent2: R=-848.0 P=2
# Epizod 6300 | Agent1: R= -44.0 P=2 | Agent2: R= -22.0 P=1
# Epizod 6400 | Agent1: R= -74.0 P=2 | Agent2: R= -25.0 P=1
# Epizod 6500 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 6300 | Agent1: R= -44.0 P=2 | Agent2: R= -22.0 P=1
# Epizod 6400 | Agent1: R= -74.0 P=2 | Agent2: R= -25.0 P=1
# Epizod 6500 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 6600 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 6700 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 6600 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 6700 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 6800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6900 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 7000 | Agent1: R= -28.0 P=2 | Agent2: R= -64.0 P=1
# Epizod 6800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6900 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 7000 | Agent1: R= -28.0 P=2 | Agent2: R= -64.0 P=1
# Epizod 7100 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 7200 | Agent1: R= -40.0 P=2 | Agent2: R= -18.0 P=1
# Epizod 7100 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 7200 | Agent1: R= -40.0 P=2 | Agent2: R= -18.0 P=1
# Epizod 7300 | Agent1: R= -44.0 P=2 | Agent2: R= -24.0 P=1
# Epizod 7400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 7500 | Agent1: R= -14.0 P=2 | Agent2: R= -26.0 P=0
# Epizod 7300 | Agent1: R= -44.0 P=2 | Agent2: R= -24.0 P=1
# Epizod 7400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 7500 | Agent1: R= -14.0 P=2 | Agent2: R= -26.0 P=0
# Epizod 7600 | Agent1: R= -18.0 P=2 | Agent2: R= -30.0 P=0
# Epizod 7700 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 7600 | Agent1: R= -18.0 P=2 | Agent2: R= -30.0 P=0
# Epizod 7700 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 7800 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 7900 | Agent1: R=-835.0 P=2 | Agent2: R=-552.0 P=1
# Epizod 7800 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 7900 | Agent1: R=-835.0 P=2 | Agent2: R=-552.0 P=1
# Epizod 8000 | Agent1: R=-267.0 P=2 | Agent2: R=-366.0 P=0
# Epizod 8100 | Agent1: R= -50.0 P=2 | Agent2: R= -30.0 P=1
# Epizod 8200 | Agent1: R= -44.0 P=2 | Agent2: R= -22.0 P=1
# Epizod 8000 | Agent1: R=-267.0 P=2 | Agent2: R=-366.0 P=0
# Epizod 8100 | Agent1: R= -50.0 P=2 | Agent2: R= -30.0 P=1
# Epizod 8200 | Agent1: R= -44.0 P=2 | Agent2: R= -22.0 P=1
# Epizod 8300 | Agent1: R= -60.0 P=2 | Agent2: R=-132.0 P=0
# Epizod 8400 | Agent1: R= -26.0 P=2 | Agent2: R= -89.0 P=1
# Epizod 8300 | Agent1: R= -60.0 P=2 | Agent2: R=-132.0 P=0
# Epizod 8400 | Agent1: R= -26.0 P=2 | Agent2: R= -89.0 P=1
# Epizod 8500 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 8600 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 8700 | Agent1: R=-380.0 P=2 | Agent2: R=-224.0 P=0
# Epizod 8500 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 8600 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 8700 | Agent1: R=-380.0 P=2 | Agent2: R=-224.0 P=0
# Epizod 8800 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 8900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9000 | Agent1: R= -10.0 P=2 | Agent2: R= -22.0 P=0
# Epizod 8800 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 8900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9000 | Agent1: R= -10.0 P=2 | Agent2: R= -22.0 P=0
# Epizod 9100 | Agent1: R=-535.0 P=1 | Agent2: R=-393.0 P=2
# Epizod 9200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9100 | Agent1: R=-535.0 P=1 | Agent2: R=-393.0 P=2
# Epizod 9200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9400 | Agent1: R= -31.0 P=2 | Agent2: R= -38.0 P=1
# Epizod 9500 | Agent1: R= -26.0 P=2 | Agent2: R= -33.0 P=1
# Epizod 9300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9400 | Agent1: R= -31.0 P=2 | Agent2: R= -38.0 P=1
# Epizod 9500 | Agent1: R= -26.0 P=2 | Agent2: R= -33.0 P=1
# Epizod 9600 | Agent1: R= -40.0 P=2 | Agent2: R= -18.0 P=1
# Epizod 9700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9800 | Agent1: R= -40.0 P=2 | Agent2: R= -18.0 P=1
# Epizod 9600 | Agent1: R= -40.0 P=2 | Agent2: R= -18.0 P=1
# Epizod 9700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 9800 | Agent1: R= -40.0 P=2 | Agent2: R= -18.0 P=1
# Epizod 9900 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 10000 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
#
# Agent 5 (Q-Learning) zna 80135 stanów
# Agent 6 (ExpectedSARSA) zna 80135 stanów
# Epizod 9900 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 10000 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
#
# Agent 5 (Q-Learning) zna 80135 stanów
# Agent 6 (ExpectedSARSA) zna 80135 stanów
# Agent 5 (QLearning): Łącznie punktów: 18436, Średnia nagroda: -144.2
# Agent 6 (ExpectedSarsa):      Łącznie punktów: 10405, Średnia nagroda: -115.0
#
# === TESTOWANIE WYTRENOWANEJ POLITYKI (Q-Learning vs ExpectedSARSA) ===
#
# ==================================================
# GRA TESTOWA 1
# ==================================================
# Krok  1: A1=\/ DÓŁ, A2=>> PRAWO | R1=-1 R2=-1
# Krok  2: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  2: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  3: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  3: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  4: A1=\/ DÓŁ, A2=/\ GÓRA | R1=+1 R2=-1 T: A1
# Krok  4: A1=\/ DÓŁ, A2=/\ GÓRA | R1=+1 R2=-1 T: A1
# Krok  5: A1=/\ GÓRA, A2=/\ GÓRA | R1=-1 R2=+1 T: A2
# Krok  5: A1=/\ GÓRA, A2=/\ GÓRA | R1=-1 R2=+1 T: A2
# Krok  6: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  6: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  7: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  7: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  8: A1=/\ GÓRA, A2=\/ DÓŁ | R1=+4 R2=-1 [H]: A1
# Krok  8: A1=/\ GÓRA, A2=\/ DÓŁ | R1=+4 R2=-1 [H]: A1
# Krok  9: A1=>> PRAWO, A2=\/ DÓŁ | R1=-1 R2=+4 [H]: A2
# Krok  9: A1=>> PRAWO, A2=\/ DÓŁ | R1=-1 R2=+4 [H]: A2
# Krok 10: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 10: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 11: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 11: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 12: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 12: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 13: A1=\/ DÓŁ, A2=<< LEWO | R1=-1 R2=-1
# Krok 13: A1=\/ DÓŁ, A2=<< LEWO | R1=-1 R2=-1
# Krok 14: A1=\/ DÓŁ, A2=/\ GÓRA | R1=+1 R2=-1 T: A1
# Krok 14: A1=\/ DÓŁ, A2=/\ GÓRA | R1=+1 R2=-1 T: A1
# Krok 15: A1=/\ GÓRA, A2=/\ GÓRA | R1=-1 R2=-1
# Krok 15: A1=/\ GÓRA, A2=/\ GÓRA | R1=-1 R2=-1
# Krok 16: A1=/\ GÓRA, A2=/\ GÓRA | R1=-1 R2=-1
# Krok 16: A1=/\ GÓRA, A2=/\ GÓRA | R1=-1 R2=-1
# Krok 17: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 17: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 18: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 18: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 19: A1=<< LEWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 19: A1=<< LEWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 20: A1=<< LEWO, A2=<< LEWO | R1=+4 R2=-1 [H]: A1
# Krok 20: A1=<< LEWO, A2=<< LEWO | R1=+4 R2=-1 [H]: A1
#
# ==================================================
# 🏁 KONIEC GRY 1 (w 20 krokach)
# Wynik końcowy:
#   Agent 1 (SARSA-λ): 2 punktów
#   Agent 2 (Double-Q): 1 punktów
#
# WYGRYWA Agent 1 z przewagą 1 punktów!
# ==================================================
#
# ==================================================
# 🏁 KONIEC GRY 1 (w 20 krokach)
# Wynik końcowy:
#   Agent 1 (SARSA-λ): 2 punktów
#   Agent 2 (Double-Q): 1 punktów
#
# WYGRYWA Agent 1 z przewagą 1 punktów!
# ==================================================

# %%
if SAVE_AGENTS:
    try:
        import dill
    except ImportError:
        import subprocess
        import sys
        subprocess.check_call([sys.executable, "-m", "pip", "install", "dill"])
        import dill

    import os

    # Zapisz obu agentów do jednego pliku jako słownik
    agents_dict = {
        'agent1': agent5,
        'agent2': agent6,
        'description': 'Q-Learning vs ExpectedSARSA'
    }

    with open('agents_QLearning_vs_ExpectedSARSA.pkl', 'wb') as f:
        dill.dump(agents_dict, f)
    print("[OK] Agenci zapisani jako: agents_QLearning_vs_ExpectedSARSA.pkl")

    # Pokaz statystyki
    print("\n=== Statystyki zapisanych agentow ===")
    print(f"Agent 1 (Q-Learning):    {len(agent5._qvalues)} znanych stanow")
    print(f"Agent 2 (ExpectedSARSA): {len(agent6._qvalues)} znanych stanow")

    print("\n[>] Pliki zapisane w folderze:")
    print(f"    {os.path.abspath('.')}")
    print("\n[>] Teraz mozesz uruchomic:")
    print("    python test_game.py")
# Out:
# [OK] Agenci zapisani jako: agents_QLearning_vs_ExpectedSARSA.pkl
#
# === Statystyki zapisanych agentow ===
# Agent 1 (Q-Learning):    80135 znanych stanow
# Agent 2 (ExpectedSARSA): 80135 znanych stanow
#
# [>] Pliki zapisane w folderze:
#     c:\Users\jasin\.Astudia\ucz_ze_wzmoc\treasurerEnv
#
# [>] Teraz mozesz uruchomic:
#     python test_game.py

# %% [markdown]
# ### SARSA vs SARSA:

# %%
import matplotlib.pyplot as plt
env = MultiTreasureHunterMDP(MAP3)
state = env.reset()

agent_SARSA1 = SARSAAgent(
    alpha=0.1, epsilon=0.15, discount=0.9,
    get_legal_actions=lambda s: env3.get_possible_actions(s, agent_id='1')
)

agent_SARSA2 = SARSAAgent(
    alpha=0.1, epsilon=0.15, discount=0.9,
    get_legal_actions=lambda s: env3.get_possible_actions(s, agent_id='2')
)

print("\nTrening agentów SARSA:")
rewards5, rewards6, scores5, scores6 = play_and_train_multi(env, agent_SARSA1, agent_SARSA2, episodes=6000)

# print(f"\nAgent 5 (Q-Learning) zna {len(agent5._qvalues)} stanów")
# print(f"Agent 6 (ExpectedSARSA) zna {len(agent6._qvalues)} stanów")

# Wykresy porównawcze
plt.figure(figsize=(14, 10))

# Nagrody agentów
plt.subplot(2, 2, 1)
plt.plot(rewards5, label='Agent (SARSA1)', alpha=0.7, color='green')
plt.plot(rewards6, label='Agent (SARSA2)', alpha=0.7, color='orange')
plt.title("Nagrody na epizod")
plt.xlabel("Epizod")
plt.ylabel("Nagroda")
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(scores5, label='Agent SARSA1', color='green', alpha=0.7)
plt.plot(scores6, label='Agent SARSA2', color='orange', alpha=0.7)
plt.title("Zebrane skarby (punkty)")
plt.xlabel("Epizod")
plt.ylabel("Punkty")
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
window = 100
if len(rewards5) >= window:
    avg_r5 = np.convolve(rewards5, np.ones(window)/window, mode='valid')
    avg_r6 = np.convolve(rewards6, np.ones(window)/window, mode='valid')
    plt.plot(avg_r5, label='Agent S1 (średnia)', linewidth=2, color='green')
    plt.plot(avg_r6, label='Agent S2 (średnia)', linewidth=2, color='orange')
    plt.title(f"Średnia krocząca nagród ({window} epizodów)")
    plt.xlabel("Epizod")
    plt.ylabel("Średnia nagroda")
    plt.legend()
    plt.grid(True)

plt.subplot(2, 2, 4)
total_scores5 = sum(scores5)
total_scores6 = sum(scores6)
plt.bar(['Agent (SARSA1)', 'Agent 6(SARSA2)'], 
        [total_scores5, total_scores6], 
        color=['green', 'orange'], alpha=0.7)
plt.title("Łączna liczba zebranych skarbów")
plt.ylabel("Suma punktów")
plt.grid(True, axis='y')

plt.tight_layout()
plt.show()

print(f"Agent 5 (SARSA1): Łącznie punktów: {total_scores5}, Średnia nagroda: {np.mean(rewards5):.1f}")
print(f"Agent 6 (SARSA2):      Łącznie punktów: {total_scores6}, Średnia nagroda: {np.mean(rewards6):.1f}")

print("\n=== TESTOWANIE WYTRENOWANEJ POLITYKI (Q-Learning vs ExpectedSARSA) ===")
test_policy(env, agent_SARSA1, agent_SARSA2, episodes=1, delay=0.3)
# Out:
# Trening agentów SARSA:
# Epizod  100 | Agent1: R=-354.0 P=1 | Agent2: R=-209.0 P=1
# Epizod  100 | Agent1: R=-354.0 P=1 | Agent2: R=-209.0 P=1
# Epizod  200 | Agent1: R=-473.0 P=1 | Agent2: R=-323.0 P=2
# Epizod  300 | Agent1: R=-218.0 P=2 | Agent2: R=-281.0 P=1
# Epizod  200 | Agent1: R=-473.0 P=1 | Agent2: R=-323.0 P=2
# Epizod  300 | Agent1: R=-218.0 P=2 | Agent2: R=-281.0 P=1
# Epizod  400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod  400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod  500 | Agent1: R= -20.0 P=2 | Agent2: R= -27.0 P=1
# Epizod  600 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod  500 | Agent1: R= -20.0 P=2 | Agent2: R= -27.0 P=1
# Epizod  600 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod  700 | Agent1: R= -82.0 P=2 | Agent2: R= -91.0 P=1
# Epizod  800 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod  900 | Agent1: R=-309.0 P=2 | Agent2: R=-227.0 P=1
# Epizod  700 | Agent1: R= -82.0 P=2 | Agent2: R= -91.0 P=1
# Epizod  800 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod  900 | Agent1: R=-309.0 P=2 | Agent2: R=-227.0 P=1
# Epizod 1000 | Agent1: R=-185.0 P=2 | Agent2: R=-219.0 P=1
# Epizod 1100 | Agent1: R=-1559.0 P=0 | Agent2: R=-977.0 P=2
# Epizod 1200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1000 | Agent1: R=-185.0 P=2 | Agent2: R=-219.0 P=1
# Epizod 1100 | Agent1: R=-1559.0 P=0 | Agent2: R=-977.0 P=2
# Epizod 1200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1300 | Agent1: R= -16.0 P=2 | Agent2: R= -30.0 P=0
# Epizod 1400 | Agent1: R=-124.0 P=1 | Agent2: R= -59.0 P=2
# Epizod 1500 | Agent1: R= -68.0 P=2 | Agent2: R= -75.0 P=1
# Epizod 1300 | Agent1: R= -16.0 P=2 | Agent2: R= -30.0 P=0
# Epizod 1400 | Agent1: R=-124.0 P=1 | Agent2: R= -59.0 P=2
# Epizod 1500 | Agent1: R= -68.0 P=2 | Agent2: R= -75.0 P=1
# Epizod 1600 | Agent1: R= -66.0 P=1 | Agent2: R= -59.0 P=2
# Epizod 1700 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 1800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1600 | Agent1: R= -66.0 P=1 | Agent2: R= -59.0 P=2
# Epizod 1700 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 1800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 1900 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 2000 | Agent1: R= -65.0 P=1 | Agent2: R= -58.0 P=2
# Epizod 2100 | Agent1: R=-206.0 P=2 | Agent2: R=-126.0 P=1
# Epizod 1900 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 2000 | Agent1: R= -65.0 P=1 | Agent2: R= -58.0 P=2
# Epizod 2100 | Agent1: R=-206.0 P=2 | Agent2: R=-126.0 P=1
# Epizod 2200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2300 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 2400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2300 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 2400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2900 | Agent1: R=-804.0 P=2 | Agent2: R=-724.0 P=1
# Epizod 3000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3100 | Agent1: R= -62.0 P=2 | Agent2: R= -76.0 P=0
# Epizod 3200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2800 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 2900 | Agent1: R=-804.0 P=2 | Agent2: R=-724.0 P=1
# Epizod 3000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3100 | Agent1: R= -62.0 P=2 | Agent2: R= -76.0 P=0
# Epizod 3200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3700 | Agent1: R=-305.0 P=2 | Agent2: R=-312.0 P=1
# Epizod 3800 | Agent1: R= -54.0 P=2 | Agent2: R= -37.0 P=0
# Epizod 3900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 3700 | Agent1: R=-305.0 P=2 | Agent2: R=-312.0 P=1
# Epizod 3800 | Agent1: R= -54.0 P=2 | Agent2: R= -37.0 P=0
# Epizod 3900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4100 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4400 | Agent1: R= -28.0 P=2 | Agent2: R= -35.0 P=1
# Epizod 4500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4800 | Agent1: R=-260.0 P=1 | Agent2: R=-197.0 P=2
# Epizod 4900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5100 | Agent1: R=-626.0 P=0 | Agent2: R=-509.0 P=1
# Epizod 5200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4400 | Agent1: R= -28.0 P=2 | Agent2: R= -35.0 P=1
# Epizod 4500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 4800 | Agent1: R=-260.0 P=1 | Agent2: R=-197.0 P=2
# Epizod 4900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5100 | Agent1: R=-626.0 P=0 | Agent2: R=-509.0 P=1
# Epizod 5200 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5300 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5400 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5500 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5600 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5700 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5800 | Agent1: R= -14.0 P=2 | Agent2: R= -26.0 P=0
# Epizod 5900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 5800 | Agent1: R= -14.0 P=2 | Agent2: R= -26.0 P=0
# Epizod 5900 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Epizod 6000 | Agent1: R=  -6.0 P=2 | Agent2: R= -13.0 P=1
# Agent 5 (SARSA1): Łącznie punktów: 11310, Średnia nagroda: -117.8
# Agent 6 (SARSA2):      Łącznie punktów: 6207, Średnia nagroda: -99.4
#
# === TESTOWANIE WYTRENOWANEJ POLITYKI (Q-Learning vs ExpectedSARSA) ===
#
# ==================================================
# GRA TESTOWA 1
# ==================================================
# Krok  1: A1=\/ DÓŁ, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  2: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  2: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  3: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  3: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  4: A1=\/ DÓŁ, A2=/\ GÓRA | R1=+1 R2=-1 T: A1
# Krok  4: A1=\/ DÓŁ, A2=/\ GÓRA | R1=+1 R2=-1 T: A1
# Krok  5: A1=/\ GÓRA, A2=/\ GÓRA | R1=-1 R2=+1 T: A2
# Krok  5: A1=/\ GÓRA, A2=/\ GÓRA | R1=-1 R2=+1 T: A2
# Krok  6: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  6: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  7: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  7: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  8: A1=/\ GÓRA, A2=\/ DÓŁ | R1=+4 R2=-1 [H]: A1
# Krok  8: A1=/\ GÓRA, A2=\/ DÓŁ | R1=+4 R2=-1 [H]: A1
# Krok  9: A1=>> PRAWO, A2=\/ DÓŁ | R1=-1 R2=+4 [H]: A2
# Krok  9: A1=>> PRAWO, A2=\/ DÓŁ | R1=-1 R2=+4 [H]: A2
# Krok 10: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 10: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 11: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 11: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 12: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 12: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 13: A1=\/ DÓŁ, A2=>> PRAWO | R1=-1 R2=-1
# Krok 13: A1=\/ DÓŁ, A2=>> PRAWO | R1=-1 R2=-1
# Krok 14: A1=\/ DÓŁ, A2=/\ GÓRA | R1=+1 R2=-1 T: A1
# Krok 14: A1=\/ DÓŁ, A2=/\ GÓRA | R1=+1 R2=-1 T: A1
# Krok 15: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 15: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 16: A1=/\ GÓRA, A2=>> PRAWO | R1=-1 R2=-1
# Krok 16: A1=/\ GÓRA, A2=>> PRAWO | R1=-1 R2=-1
# Krok 17: A1=<< LEWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 17: A1=<< LEWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 18: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 18: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 19: A1=<< LEWO, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 19: A1=<< LEWO, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 20: A1=<< LEWO, A2=>> PRAWO | R1=+4 R2=-1 [H]: A1
# Krok 20: A1=<< LEWO, A2=>> PRAWO | R1=+4 R2=-1 [H]: A1
#
# ==================================================
# 🏁 KONIEC GRY 1 (w 20 krokach)
# Wynik końcowy:
#   Agent 1 (SARSA-λ): 2 punktów
#   Agent 2 (Double-Q): 1 punktów
#
# WYGRYWA Agent 1 z przewagą 1 punktów!
# ==================================================
#
# ==================================================
# 🏁 KONIEC GRY 1 (w 20 krokach)
# Wynik końcowy:
#   Agent 1 (SARSA-λ): 2 punktów
#   Agent 2 (Double-Q): 1 punktów
#
# WYGRYWA Agent 1 z przewagą 1 punktów!
# ==================================================

# %%
if SAVE_AGENTS:
    try:
        import dill
    except ImportError:
        import subprocess
        import sys
        subprocess.check_call([sys.executable, "-m", "pip", "install", "dill"])
        import dill

    import os

    agents_dict = {
        'agent1': agent_SARSA1,
        'agent2': agent_SARSA2,
        'description': 'SARSA vs SARSA'
    }

    with open('agents_SARSA_vs_SARSA.pkl', 'wb') as f:
        dill.dump(agents_dict, f)
    print("[OK] Agenci zapisani jako: agents_SARSA_vs_SARSA.pkl")

    print("\n=== Statystyki zapisanych agentow ===")
    print(f"Agent 1 (SARSA1):    {len(agent_SARSA1._qvalues)} znanych stanow")
    print(f"Agent 2 (SARSA2): {len(agent_SARSA2._qvalues)} znanych stanow")

    print("\n[>] Pliki zapisane w folderze:")
    print(f"    {os.path.abspath('.')}")
    print("\n[>] Teraz mozesz uruchomic:")
    print("    python test_game.py")

# %% [markdown]
# ### SARSALambda vs Double-Q-Learning:

# %%
env = MultiTreasureHunterMDP(MAP3)
state = env.reset()

agent1 = SARSALambdaAgent(
    alpha=0.1, epsilon=0.5, discount=0.99,
    get_legal_actions=lambda s: env.get_possible_actions(s, agent_id='1'),
    lambda_value=0.9
)
agent2 = DQLearningAgent(
    alpha=0.1, epsilon=0.5, discount=0.99,
    get_legal_actions=lambda s: env.get_possible_actions(s, agent_id='2')
)

print("Trening agentów:")
rewards1, rewards2, scores1, scores2 = play_and_train_multi(env, agent1, agent2, episodes=6000)

print(f"Agent 1 zna {len(agent1._qvalues)} stanów")
print(f"Agent 2 zna {len(agent2._qvaluesA) + len(agent2._qvaluesB)} stanów (z obu tabel)")

# Wykresy porównawcze dla obu agentów
plt.figure(figsize=(14, 10))

# Nagrody agentów
plt.subplot(2, 2, 1)
plt.plot(rewards1, label='Agent 1 (SARSA-λ)', alpha=0.7)
plt.plot(rewards2, label='Agent 2 (Double-Q)', alpha=0.7)
plt.title("Nagrody na epizod")
plt.xlabel("Epizod")
plt.ylabel("Nagroda")
plt.legend()
plt.grid(True)

# Punkty (zebrane skarby) agentów
plt.subplot(2, 2, 2)
plt.plot(scores1, label='Agent 1 (SARSA-λ)', color='blue', alpha=0.7)
plt.plot(scores2, label='Agent 2 (Double-Q)', color='red', alpha=0.7)
plt.title("Zebrane skarby (punkty)")
plt.xlabel("Epizod")
plt.ylabel("Punkty")
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
window = 100
if len(rewards1) >= window:
    avg_r1 = np.convolve(rewards1, np.ones(window)/window, mode='valid')
    avg_r2 = np.convolve(rewards2, np.ones(window)/window, mode='valid')
    plt.plot(avg_r1, label='Agent 1 (średnia)', linewidth=2)
    plt.plot(avg_r2, label='Agent 2 (średnia)', linewidth=2)
    plt.title(f"Średnia krocząca nagród ({window} epizodów)")
    plt.xlabel("Epizod")
    plt.ylabel("Średnia nagroda")
    plt.legend()
    plt.grid(True)

# Porównanie całkowitych punktów
plt.subplot(2, 2, 4)
total_scores1 = sum(scores1)
total_scores2 = sum(scores2)
plt.bar(['Agent 1\n(SARSA-λ)', 'Agent 2\n(Double-Q)'], 
        [total_scores1, total_scores2], 
        color=['blue', 'red'], alpha=0.7)
plt.title("Łączna liczba zebranych skarbów")
plt.ylabel("Suma punktów")
plt.grid(True, axis='y')

plt.tight_layout()
plt.show()

print(f"\n=== PODSUMOWANIE ===")
print(f"Agent 1 (SARSA-λ):  Łącznie punktów: {total_scores1}, Średnia nagroda: {np.mean(rewards1):.1f}")
print(f"Agent 2 (Double-Q): Łącznie punktów: {total_scores2}, Średnia nagroda: {np.mean(rewards2):.1f}")

print("\n=== TESTOWANIE WYTRENOWANEJ POLITYKI ===")
test_policy(env, agent1, agent2, episodes=1)
# Out:
# Trening agentów:
# Epizod  100 | Agent1: R=-2577.0 P=0 | Agent2: R=-1660.0 P=2
# Epizod  100 | Agent1: R=-2577.0 P=0 | Agent2: R=-1660.0 P=2
# Epizod  200 | Agent1: R=-132.0 P=2 | Agent2: R= -54.0 P=1
# Epizod  200 | Agent1: R=-132.0 P=2 | Agent2: R= -54.0 P=1
# Epizod  300 | Agent1: R=-631.0 P=2 | Agent2: R=-325.0 P=1
# Epizod  300 | Agent1: R=-631.0 P=2 | Agent2: R=-325.0 P=1
# Epizod  400 | Agent1: R= -24.0 P=2 | Agent2: R= -31.0 P=1
# Epizod  400 | Agent1: R= -24.0 P=2 | Agent2: R= -31.0 P=1
# Epizod  500 | Agent1: R= -26.0 P=2 | Agent2: R= -33.0 P=1
# Epizod  500 | Agent1: R= -26.0 P=2 | Agent2: R= -33.0 P=1
# Epizod  600 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod  600 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod  700 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod  700 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod  800 | Agent1: R= -54.0 P=2 | Agent2: R= -61.0 P=1
# Epizod  800 | Agent1: R= -54.0 P=2 | Agent2: R= -61.0 P=1
# Epizod  900 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod  900 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 1000 | Agent1: R= -22.0 P=2 | Agent2: R= -29.0 P=1
# Epizod 1100 | Agent1: R= -16.0 P=2 | Agent2: R= -23.0 P=1
# Epizod 1000 | Agent1: R= -22.0 P=2 | Agent2: R= -29.0 P=1
# Epizod 1100 | Agent1: R= -16.0 P=2 | Agent2: R= -23.0 P=1
# Epizod 1200 | Agent1: R=-112.0 P=2 | Agent2: R= -90.0 P=1
# Epizod 1200 | Agent1: R=-112.0 P=2 | Agent2: R= -90.0 P=1
# Epizod 1300 | Agent1: R= -18.0 P=2 | Agent2: R= -25.0 P=1
# Epizod 1300 | Agent1: R= -18.0 P=2 | Agent2: R= -25.0 P=1
# Epizod 1400 | Agent1: R= -14.0 P=2 | Agent2: R= -50.0 P=1
# Epizod 1400 | Agent1: R= -14.0 P=2 | Agent2: R= -50.0 P=1
# Epizod 1500 | Agent1: R= -16.0 P=2 | Agent2: R= -23.0 P=1
# Epizod 1500 | Agent1: R= -16.0 P=2 | Agent2: R= -23.0 P=1
# Epizod 1600 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 1600 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 1700 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 1800 | Agent1: R= -40.0 P=2 | Agent2: R= -47.0 P=1
# Epizod 1700 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 1800 | Agent1: R= -40.0 P=2 | Agent2: R= -47.0 P=1
# Epizod 1900 | Agent1: R= -18.0 P=2 | Agent2: R= -25.0 P=1
# Epizod 2000 | Agent1: R= -16.0 P=2 | Agent2: R= -23.0 P=1
# Epizod 1900 | Agent1: R= -18.0 P=2 | Agent2: R= -25.0 P=1
# Epizod 2000 | Agent1: R= -16.0 P=2 | Agent2: R= -23.0 P=1
# Epizod 2100 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 2100 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 2200 | Agent1: R= -30.0 P=2 | Agent2: R= -37.0 P=1
# Epizod 2200 | Agent1: R= -30.0 P=2 | Agent2: R= -37.0 P=1
# Epizod 2300 | Agent1: R=-376.0 P=2 | Agent2: R=-271.0 P=1
# Epizod 2300 | Agent1: R=-376.0 P=2 | Agent2: R=-271.0 P=1
# Epizod 2400 | Agent1: R= -31.0 P=2 | Agent2: R= -38.0 P=1
# Epizod 2500 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 2400 | Agent1: R= -31.0 P=2 | Agent2: R= -38.0 P=1
# Epizod 2500 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 2600 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 2700 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 2800 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 2600 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 2700 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 2800 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 2900 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 3000 | Agent1: R= -16.0 P=2 | Agent2: R= -23.0 P=1
# Epizod 3100 | Agent1: R= -22.0 P=2 | Agent2: R= -29.0 P=1
# Epizod 3200 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 3300 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 2900 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 3000 | Agent1: R= -16.0 P=2 | Agent2: R= -23.0 P=1
# Epizod 3100 | Agent1: R= -22.0 P=2 | Agent2: R= -29.0 P=1
# Epizod 3200 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 3300 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 3400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 3500 | Agent1: R= -24.0 P=2 | Agent2: R= -31.0 P=1
# Epizod 3600 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 3700 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 3400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 3500 | Agent1: R= -24.0 P=2 | Agent2: R= -31.0 P=1
# Epizod 3600 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 3700 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 3800 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 3900 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4000 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 4100 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 4200 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4300 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 3800 | Agent1: R= -14.0 P=2 | Agent2: R= -21.0 P=1
# Epizod 3900 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4000 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 4100 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 4200 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4300 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4500 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 4600 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4700 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 4800 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 4900 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5000 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4500 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 4600 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 4700 | Agent1: R= -10.0 P=2 | Agent2: R= -17.0 P=1
# Epizod 4800 | Agent1: R= -12.0 P=2 | Agent2: R= -19.0 P=1
# Epizod 4900 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5000 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5100 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5200 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5300 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5500 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5100 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5200 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5300 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5400 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5500 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5600 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5700 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5800 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5900 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 6000 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Agent 1 zna 43086 stanów
# Agent 2 zna 86172 stanów (z obu tabel)
# Epizod 5600 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5700 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5800 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 5900 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Epizod 6000 | Agent1: R=  -8.0 P=2 | Agent2: R= -15.0 P=1
# Agent 1 zna 43086 stanów
# Agent 2 zna 86172 stanów (z obu tabel)
# === PODSUMOWANIE ===
# Agent 1 (SARSA-λ):  Łącznie punktów: 11649, Średnia nagroda: -120.2
# Agent 2 (Double-Q): Łącznie punktów: 6122, Średnia nagroda: -98.5
#
# === TESTOWANIE WYTRENOWANEJ POLITYKI ===
#
# ==================================================
# GRA TESTOWA 1
# ==================================================
# Krok  1: A1=\/ DÓŁ, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  2: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  2: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  3: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  3: A1=\/ DÓŁ, A2=/\ GÓRA | R1=-1 R2=-1
# Krok  4: A1=\/ DÓŁ, A2=/\ GÓRA | R1=+1 R2=-1 T: A1
# Krok  4: A1=\/ DÓŁ, A2=/\ GÓRA | R1=+1 R2=-1 T: A1
# Krok  5: A1=/\ GÓRA, A2=/\ GÓRA | R1=-1 R2=+1 T: A2
# Krok  5: A1=/\ GÓRA, A2=/\ GÓRA | R1=-1 R2=+1 T: A2
# Krok  6: A1=>> PRAWO, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  6: A1=>> PRAWO, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  7: A1=<< LEWO, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  7: A1=<< LEWO, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  8: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  8: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok  9: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=+4 [H]: A2
# Krok  9: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=+4 [H]: A2
# Krok 10: A1=/\ GÓRA, A2=\/ DÓŁ | R1=+4 R2=-1 [H]: A1
# Krok 10: A1=/\ GÓRA, A2=\/ DÓŁ | R1=+4 R2=-1 [H]: A1
# Krok 11: A1=>> PRAWO, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 11: A1=>> PRAWO, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 12: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 12: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 13: A1=>> PRAWO, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 13: A1=>> PRAWO, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 14: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 14: A1=>> PRAWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 15: A1=\/ DÓŁ, A2=>> PRAWO | R1=-1 R2=-1
# Krok 15: A1=\/ DÓŁ, A2=>> PRAWO | R1=-1 R2=-1
# Krok 16: A1=\/ DÓŁ, A2=>> PRAWO | R1=+1 R2=-1 T: A1
# Krok 16: A1=\/ DÓŁ, A2=>> PRAWO | R1=+1 R2=-1 T: A1
# Krok 17: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 17: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 18: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 18: A1=/\ GÓRA, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 19: A1=<< LEWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 19: A1=<< LEWO, A2=<< LEWO | R1=-1 R2=-1
# Krok 20: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 20: A1=<< LEWO, A2=>> PRAWO | R1=-1 R2=-1
# Krok 21: A1=<< LEWO, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 21: A1=<< LEWO, A2=\/ DÓŁ | R1=-1 R2=-1
# Krok 22: A1=<< LEWO, A2=>> PRAWO | R1=+4 R2=-1 [H]: A1
# Krok 22: A1=<< LEWO, A2=>> PRAWO | R1=+4 R2=-1 [H]: A1
#
# ==================================================
# 🏁 KONIEC GRY 1 (w 22 krokach)
# Wynik końcowy:
#   Agent 1 (SARSA-λ): 2 punktów
#   Agent 2 (Double-Q): 1 punktów
#
# WYGRYWA Agent 1 z przewagą 1 punktów!
# ==================================================
#
# ==================================================
# 🏁 KONIEC GRY 1 (w 22 krokach)
# Wynik końcowy:
#   Agent 1 (SARSA-λ): 2 punktów
#   Agent 2 (Double-Q): 1 punktów
#
# WYGRYWA Agent 1 z przewagą 1 punktów!
# ==================================================

# %%
if SAVE_AGENTS:
    try:
        import dill
    except ImportError:
        import subprocess
        import sys
        subprocess.check_call([sys.executable, "-m", "pip", "install", "dill"])
        import dill

    import os

    # Zapisz obu agentów do jednego pliku jako słownik
    agents_dict = {
        'agent1': agent1,
        'agent2': agent2,
        'description': 'SARSA-Lambda vs Double-Q-Learning'
    }

    with open('agents_SARSALambda_vs_DoubleQ.pkl', 'wb') as f:
        dill.dump(agents_dict, f)
    print("[OK] Agenci zapisani jako: agents_SARSALambda_vs_DoubleQ.pkl")

    # Pokaz statystyki
    print("\n=== Statystyki zapisanych agentow ===")
    print(f"Agent 1 (SARSA Lambda):      {len(agent1._qvalues)} znanych stanow")
    print(f"Agent 2 (Double-Q-Learning): {len(agent2._qvaluesA) + len(agent2._qvaluesB)} znanych stanow (z obu tabel)")

    print("\n[>] Pliki zapisane w folderze:")
    print(f"    {os.path.abspath('.')}")
    print("\n[>] Teraz mozesz uruchomic:")
    print("    python test_game.py")
