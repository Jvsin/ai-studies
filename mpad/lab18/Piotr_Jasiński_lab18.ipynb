# %% [markdown]
# # Laboratorium 18

# %% [markdown]
# Wartości tabeli Alarm przed uczeniem:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Oznaczamy wszystkie nody, poza Alarmem jako Fixed Nodes. Ich tabeli nie aktualizujemy.
#
# System uczony był na pliku *Holmes alarm data.txt*.
#
# Parametr **confidence** został ustawiony na 0.5, by zachować poprzednią wiedzę.

# %% [markdown]
# ### Wynik po nauce:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Wyniki nie zmieniły się diametralnie, jedynie wzorsło nieco prawdopodobieństwo Alarmu, w przypadku wystąpienia Trzęsienia ziemi przy braku włamania.

# %% [markdown]
# Nowe dane sugerują wyższe ryzyko fałszywych alarmów wywoływanych przez trzęsienia ziemi.
